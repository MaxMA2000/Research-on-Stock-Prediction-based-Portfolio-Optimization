# %% [markdown]
# # Step1: Downloading Stock Historical Data Using FUTU API

# %% [markdown]
# ---
# **What does this notebook do?**
# - This notebook downloads the 64 historical stock prices of HSI Constituent stocks and the historical Hang Seng Index price
# - **Please notice that you can SKIP RUNNING THROUGH this notebook if you are planning to use the stocks data given inside the [DataSource](../DataSource), please go directly to the step3**
#
# **What is FUTU API?**
# - Futu OpenAPI provides wide varieties of market data and trading services for your programmed trading to meet the needs of every developer's programmed trading and help your Quant dreams.
# - [FUTU Open API Official Document](https://openapi.futunn.com/futu-api-doc/en/intro/intro.html)
# - [FUTU Open API Official Github Repository](https://github.com/FutunnOpen/py-futu-api)
# ----

# %% [markdown]
# ## Import Packages

# %%
# Remember to open the FutuOpenD Desktop
from futu import *
import time
import pandas as pd
import numpy as np

# %% [markdown]
# ## Checking How Many Connection Times are available

# %%
from futu import *

def check_connection_time():
    quote_ctx = OpenQuoteContext(host='127.0.0.1', port=11111)

    ret, data = quote_ctx.get_history_kl_quota(get_detail=True)  # Set as true to represent gets back the historical K line data
    if ret == RET_OK:
        print(data)
    else:
        print('error:', data)
    quote_ctx.close() # closing the connection avoid the loss of connection times

# %%
check_connection_time()
# Out:
# 2022-01-28 15:10:25,505 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=67, host=127.0.0.1, port=11111, user_id=18813346
# (64, 236, [{'code': 'HK.00002', 'request_time': '2022-01-28 14:31:30'}, {'code': 'HK.00003', 'request_time': '2022-01-28 14:31:45'}, {'code': 'HK.00005', 'request_time': '2022-01-28 14:32:00'}, {'code': 'HK.00006', 'request_time': '2022-01-28 14:32:15'}, {'code': 'HK.00101', 'request_time': '2022-01-28 14:34:01'}, {'code': 'HK.00291', 'request_time': '2022-01-28 14:35:15'}, {'code': 'HK.00011', 'request_time': '2022-01-28 14:32:31'}, {'code': 'HK.00241', 'request_time': '2022-01-28 14:34:32'}, {'code': 'HK.00016', 'request_time': '2022-01-28 14:33:01'}, {'code': 'HK.00001', 'request_time': '2022-01-28 14:31:14'}, {'code': 'HK.00017', 'request_time': '2022-01-28 14:33:16'}, {'code': 'HK.00175', 'request_time': '2022-01-28 14:34:17'}, {'code': 'HK.00012', 'request_time': '2022-01-28 14:32:46'}, {'code': 'HK.00267', 'request_time': '2022-01-28 14:34:46'}, {'code': 'HK.00669', 'request_time': '2022-01-28 14:36:03'}, {'code': 'HK.00027', 'request_time': '2022-01-28 14:33:31'}, {'code': 'HK.00688', 'request_time': '2022-01-28 14:36:18'}, {'code': 'HK.01093', 'request_time': '2022-01-28 14:39:43'}, {'code': 'HK.01038', 'request_time': '2022-01-28 14:39:11'}, {'code': 'HK.01109', 'request_time': '2022-01-28 14:39:58'}, {'code': 'HK.00941', 'request_time': '2022-01-28 14:38:25'}, {'code': 'HK.01044', 'request_time': '2022-01-28 14:39:27'}, {'code': 'HK.00857', 'request_time': '2022-01-28 14:37:20'}, {'code': 'HK.00762', 'request_time': '2022-01-28 14:36:49'}, {'code': 'HK.00388', 'request_time': '2022-01-28 14:35:48'}, {'code': 'HK.00066', 'request_time': '2022-01-28 14:33:46'}, {'code': 'HK.00386', 'request_time': '2022-01-28 14:35:32'}, {'code': 'HK.00883', 'request_time': '2022-01-28 14:37:52'}, {'code': 'HK.02688', 'request_time': '2022-01-28 14:45:09'}, {'code': 'HK.02388', 'request_time': '2022-01-28 14:44:38'}, {'code': 'HK.01211', 'request_time': '2022-01-28 14:40:43'}, {'code': 'HK.01177', 'request_time': '2022-01-28 14:40:27'}, {'code': 'HK.02628', 'request_time': '2022-01-28 14:44:53'}, {'code': 'HK.02319', 'request_time': '2022-01-28 14:43:51'}, {'code': 'HK.00700', 'request_time': '2022-01-28 14:36:34'}, {'code': 'HK.02318', 'request_time': '2022-01-28 14:43:35'}, {'code': 'HK.02331', 'request_time': '2022-01-28 14:44:06'}, {'code': 'HK.00868', 'request_time': '2022-01-28 14:37:36'}, {'code': 'HK.02018', 'request_time': '2022-01-28 14:42:37'}, {'code': 'HK.00939', 'request_time': '2022-01-28 14:38:08'}, {'code': 'HK.02313', 'request_time': '2022-01-28 14:43:20'}, {'code': 'HK.00823', 'request_time': '2022-01-28 14:37:05'}, {'code': 'HK.03988', 'request_time': '2022-01-28 14:45:53'}, {'code': 'HK.03968', 'request_time': '2022-01-28 14:45:37'}, {'code': 'HK.01398', 'request_time': '2022-01-28 14:41:15'}, {'code': 'HK.02007', 'request_time': '2022-01-28 14:42:21'}, {'code': 'HK.02382', 'request_time': '2022-01-28 14:44:23'}, {'code': 'HK.02020', 'request_time': '2022-01-28 14:42:52'}, {'code': 'HK.00960', 'request_time': '2022-01-28 14:38:40'}, {'code': 'HK.01928', 'request_time': '2022-01-28 14:41:54'}, {'code': 'HK.01299', 'request_time': '2022-01-28 14:40:59'}, {'code': 'HK.00968', 'request_time': '2022-01-28 14:38:56'}, {'code': 'HK.00288', 'request_time': '2022-01-28 14:35:00'}, {'code': 'HK.01113', 'request_time': '2022-01-28 14:40:12'}, {'code': 'HK.02269', 'request_time': '2022-01-28 14:43:04'}, {'code': 'HK.01997', 'request_time': '2022-01-28 14:42:06'}, {'code': 'HK.06098', 'request_time': '2022-01-28 14:46:05'}, {'code': 'HK.01810', 'request_time': '2022-01-28 14:41:27'}, {'code': 'HK.03690', 'request_time': '2022-01-28 14:45:21'}, {'code': 'HK.06862', 'request_time': '2022-01-28 14:46:16'}, {'code': 'HK.01876', 'request_time': '2022-01-28 14:41:38'}, {'code': 'HK.09988', 'request_time': '2022-01-28 14:46:38'}, {'code': 'HK.09999', 'request_time': '2022-01-28 14:46:49'}, {'code': 'HK.09618', 'request_time': '2022-01-28 14:46:27'}])
# 2022-01-28 15:10:25,513 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=67

# %% [markdown]
# ## Get the List of Stocks in The Plate
# - [FUTU API: Get the List of Stocks in The Plate](https://openapi.moomoo.com/futu-api-doc/en/quote/get-plate-stock.html)

# %%
from futu import *
import pandas as pd

quote_ctx = OpenQuoteContext(host='127.0.0.1', port=11111)

ret, data = quote_ctx.get_plate_stock('HK.HSI Constituent')

if ret == RET_OK:
    print(data)
    print(data['stock_name'][0])    
    print(data['stock_name'].values.tolist())   
    full_stock_list = data
else:
    print('error:', data)
quote_ctx.close()
# Out:
# 2022-01-28 14:12:56,247 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1, host=127.0.0.1, port=11111, user_id=18813346
#         code  lot_size stock_name  stock_owner  stock_child_type stock_type  \
# 0   HK.00001       500         长和          NaN               NaN      STOCK
# 1   HK.00002       500       中电控股          NaN               NaN      STOCK
# 2   HK.00003      1000     香港中华煤气          NaN               NaN      STOCK
# 3   HK.00005       400       汇丰控股          NaN               NaN      STOCK
# 4   HK.00006       500       电能实业          NaN               NaN      STOCK
# ..       ...       ...        ...          ...               ...        ...
# 59  HK.06098      1000      碧桂园服务          NaN               NaN      STOCK
# 60  HK.06862      1000        海底捞          NaN               NaN      STOCK
# 61  HK.09618        50    京东集团-SW          NaN               NaN      STOCK
# 62  HK.09988       100    阿里巴巴-SW          NaN               NaN      STOCK
# 63  HK.09999       100       网易-S          NaN               NaN      STOCK
#
#      list_time        stock_id  main_contract last_trade_time
# 0   2015-03-18   4440996184065          False
# 1   1970-01-01               2          False
# 2   1970-01-01               3          False
# 3   1970-01-01               5          False
# 4   1976-08-16               6          False
# ..         ...             ...            ...             ...
# 59  2018-06-19  75965086570450          False
# 60  2018-09-26  76385993366222          False
# 61  2020-06-18  79100412700050          False
# 62  2019-11-26  78224239372036          False
# 63  2020-06-11  79083232831247          False
#
# [64 rows x 10 columns]
# 长和
# ['长和', '中电控股', '香港中华煤气', '汇丰控股', '电能实业', '恒生银行', '恒基地产', '新鸿基地产', '新世界发展', '银河娱乐', '港铁公司', '恒隆地产', '吉利汽车', '阿里健康', '中信股份', '万洲国际', '华润啤酒', '中国石油化工股份', '香港交易所', '创科实业', '中国海外发展', '腾讯控股', '中国联通', '领展房产基金', '中国石油股份', '信义玻璃', '中国海洋石油', '建设银行', '中国移动', '龙湖集团', '信义光能', '长江基建集团', '恒安国际', '石药集团', '华润置地', '长实集团', '中国生物制药', '比亚迪股份', '友邦保险', '工商银行', '小米集团-W', '百威亚太', '金沙中国有限公司', '九龙仓置业', '碧桂园', '瑞声科技', '安踏体育', '药明生物', '申洲国际', '中国平安', '蒙牛乳业', '李宁', '舜宇光学科技', '中银香港', '中国人寿', '新奥能源', '美团-W', '招商银行', '中国银行', '碧桂园服务', '海底捞', '京东集团-SW', '阿里巴巴-SW', '网易-S']
# 2022-01-28 14:12:56,401 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=1

# %%
full_stock_list.to_csv("full_hsi_stock_list.csv", index=False)
# full_stock_list[full_stock_list['list_time']>'2012-01-01'] ## 14 stocks are listed after '2012-01-01'

full_stock_list
# Out:
#         code  lot_size stock_name  stock_owner  stock_child_type stock_type  \
# 0   HK.00001       500         长和          NaN               NaN      STOCK
# 1   HK.00002       500       中电控股          NaN               NaN      STOCK
# 2   HK.00003      1000     香港中华煤气          NaN               NaN      STOCK
# 3   HK.00005       400       汇丰控股          NaN               NaN      STOCK
# 4   HK.00006       500       电能实业          NaN               NaN      STOCK
# ..       ...       ...        ...          ...               ...        ...
# 59  HK.06098      1000      碧桂园服务          NaN               NaN      STOCK
# 60  HK.06862      1000        海底捞          NaN               NaN      STOCK
# 61  HK.09618        50    京东集团-SW          NaN               NaN      STOCK
# 62  HK.09988       100    阿里巴巴-SW          NaN               NaN      STOCK
# 63  HK.09999       100       网易-S          NaN               NaN      STOCK
#
#      list_time        stock_id  main_contract last_trade_time
# 0   2015-03-18   4440996184065          False
# 1   1970-01-01               2          False
# 2   1970-01-01               3          False
# 3   1970-01-01               5          False
# 4   1976-08-16               6          False
# ..         ...             ...            ...             ...
# 59  2018-06-19  75965086570450          False
# 60  2018-09-26  76385993366222          False
# 61  2020-06-18  79100412700050          False
# 62  2019-11-26  78224239372036          False
# 63  2020-06-11  79083232831247          False
#
# [64 rows x 10 columns]

# %% [markdown]
# ## Developing Functions for Automatically Download All 64 Stocks

# %%
# Function - input stock code and return daily historical data from 2012-01-01 to 2022-01-01
from futu import *
import pandas as pd
import numpy as np

def futu_get_historical_data(stock_code):
    # Connect to FUTU
    quote_ctx = OpenQuoteContext(host='127.0.0.1', port=11111)

    # Request page_req_key
    ret, data, page_req_key = quote_ctx.request_history_kline(stock_code, start='2012-01-01', end='2022-01-01', max_count=10) 
    df = data

    if ret == RET_OK:
        print(f'Start downloading {stock_code} data')
#         print(data)
#         print(data['code'][0])    # get first line stock code
#         print(data['close'].values.tolist())   # list change first date closing price into list
    else:
        print('error:', data)

    while page_req_key != None:  # request all results behind
#         print('*************************************')
        ret, data, page_req_key = quote_ctx.request_history_kline(stock_code, start='2012-01-01', end='2022-01-01', max_count=10, page_req_key=page_req_key) # 请求翻页后的数据
        if ret == RET_OK:
            df = df.append(data)
#             print(data)
        else:
            print('error:', data)
    print(f'{stock_code} histocial data download are finished!')
    quote_ctx.close() # closing the connection avoid the loss of connection times
    
    filename = stock_code + '.csv'
    return df.to_csv(filename, index=False)

# %%
stock_code = 'HK.00700'
futu_get_historical_data(stock_code)
# Out:
# 2022-01-26 23:12:37,284 | 10304 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=16, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.00700 data
# HK.00700 histocial data download are finished!
# 2022-01-26 23:12:44,347 | 10304 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=16

# %% [markdown]
# HK.HSI Constituent## Download all 64 stock data in HANG SENG INDEX (HK.HSI Constituent, 恒指成份股)

# %%
def download_64_hsi_stock_data():
    HSI_stock_list = full_stock_list['code'].tolist()
    num=0
    for stock_code in HSI_stock_list:
        print(f"{num} HSI download")
        futu_get_historical_data(stock_code)
        num +=1
        print("*********************\n")
        time.sleep(10)

# %%
download_64_hsi_stock_data()
# Out:
# 0 HSI download
# 2022-01-28 14:31:08,696 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=3, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.00001 data
# HK.00001 histocial data download are finished!
# 2022-01-28 14:31:14,139 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=3
# *********************
#
# 1 HSI download
# 2022-01-28 14:31:24,182 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=4, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.00002 data
# HK.00002 histocial data download are finished!
# 2022-01-28 14:31:29,841 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=4
# *********************
#
# 2 HSI download
# 2022-01-28 14:31:39,903 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=5, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.00003 data
# HK.00003 histocial data download are finished!
# 2022-01-28 14:31:44,997 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=5
# *********************
#
# 3 HSI download
# 2022-01-28 14:31:55,140 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=6, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.00005 data
# HK.00005 histocial data download are finished!
# 2022-01-28 14:32:00,674 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=6
# *********************
#
# 4 HSI download
# 2022-01-28 14:32:10,821 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=7, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.00006 data
# HK.00006 histocial data download are finished!
# 2022-01-28 14:32:15,686 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=7
# *********************
#
# 5 HSI download
# 2022-01-28 14:32:25,719 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=8, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.00011 data
# HK.00011 histocial data download are finished!
# 2022-01-28 14:32:30,842 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=8
# *********************
#
# 6 HSI download
# 2022-01-28 14:32:40,884 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=9, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.00012 data
# HK.00012 histocial data download are finished!
# 2022-01-28 14:32:46,170 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=9
# *********************
#
# 7 HSI download
# 2022-01-28 14:32:56,329 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=10, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.00016 data
# HK.00016 histocial data download are finished!
# 2022-01-28 14:33:01,513 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=10
# *********************
#
# 8 HSI download
# 2022-01-28 14:33:11,557 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=11, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.00017 data
# HK.00017 histocial data download are finished!
# 2022-01-28 14:33:16,468 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=11
# *********************
#
# 9 HSI download
# 2022-01-28 14:33:26,593 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=12, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.00027 data
# HK.00027 histocial data download are finished!
# 2022-01-28 14:33:31,529 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=12
# *********************
#
# 10 HSI download
# 2022-01-28 14:33:41,562 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=13, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.00066 data
# HK.00066 histocial data download are finished!
# 2022-01-28 14:33:46,551 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=13
# *********************
#
# 11 HSI download
# 2022-01-28 14:33:56,584 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=14, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.00101 data
# HK.00101 histocial data download are finished!
# 2022-01-28 14:34:01,633 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=14
# *********************
#
# 12 HSI download
# 2022-01-28 14:34:11,769 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=15, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.00175 data
# HK.00175 histocial data download are finished!
# 2022-01-28 14:34:16,749 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=15
# *********************
#
# 13 HSI download
# 2022-01-28 14:34:26,886 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=16, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.00241 data
# HK.00241 histocial data download are finished!
# 2022-01-28 14:34:31,753 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=16
# *********************
#
# 14 HSI download
# 2022-01-28 14:34:41,784 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=17, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.00267 data
# HK.00267 histocial data download are finished!
# 2022-01-28 14:34:46,588 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=17
# *********************
#
# 15 HSI download
# 2022-01-28 14:34:56,737 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=18, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.00288 data
# HK.00288 histocial data download are finished!
# 2022-01-28 14:35:00,659 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=18
# *********************
#
# 16 HSI download
# 2022-01-28 14:35:10,690 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=19, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.00291 data
# HK.00291 histocial data download are finished!
# 2022-01-28 14:35:15,683 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=19
# *********************
#
# 17 HSI download
# 2022-01-28 14:35:25,726 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=20, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.00386 data
# HK.00386 histocial data download are finished!
# 2022-01-28 14:35:32,186 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=20
# *********************
#
# 18 HSI download
# 2022-01-28 14:35:42,265 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=21, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.00388 data
# HK.00388 histocial data download are finished!
# 2022-01-28 14:35:47,878 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=21
# *********************
#
# 19 HSI download
# 2022-01-28 14:35:57,905 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=22, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.00669 data
# HK.00669 histocial data download are finished!
# 2022-01-28 14:36:03,642 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=22
# *********************
#
# 20 HSI download
# 2022-01-28 14:36:13,698 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=23, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.00688 data
# HK.00688 histocial data download are finished!
# 2022-01-28 14:36:18,669 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=23
# *********************
#
# 21 HSI download
# 2022-01-28 14:36:28,702 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=24, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.00700 data
# HK.00700 histocial data download are finished!
# 2022-01-28 14:36:33,799 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=24
# *********************
#
# 22 HSI download
# 2022-01-28 14:36:43,943 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=25, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.00762 data
# HK.00762 histocial data download are finished!
# 2022-01-28 14:36:49,532 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=25
# *********************
#
# 23 HSI download
# 2022-01-28 14:36:59,608 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=26, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.00823 data
# HK.00823 histocial data download are finished!
# 2022-01-28 14:37:04,826 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=26
# *********************
#
# 24 HSI download
# 2022-01-28 14:37:14,871 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=27, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.00857 data
# HK.00857 histocial data download are finished!
# 2022-01-28 14:37:20,696 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=27
# *********************
#
# 25 HSI download
# 2022-01-28 14:37:30,737 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=28, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.00868 data
# HK.00868 histocial data download are finished!
# 2022-01-28 14:37:36,339 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=28
# *********************
#
# 26 HSI download
# 2022-01-28 14:37:46,376 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=29, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.00883 data
# HK.00883 histocial data download are finished!
# 2022-01-28 14:37:52,177 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=29
# *********************
#
# 27 HSI download
# 2022-01-28 14:38:02,310 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=30, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.00939 data
# HK.00939 histocial data download are finished!
# 2022-01-28 14:38:08,275 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=30
# *********************
#
# 28 HSI download
# 2022-01-28 14:38:18,314 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=31, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.00941 data
# HK.00941 histocial data download are finished!
# 2022-01-28 14:38:24,873 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=31
# *********************
#
# 29 HSI download
# 2022-01-28 14:38:34,913 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=32, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.00960 data
# HK.00960 histocial data download are finished!
# 2022-01-28 14:38:40,215 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=32
# *********************
#
# 30 HSI download
# 2022-01-28 14:38:50,277 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=33, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.00968 data
# HK.00968 histocial data download are finished!
# 2022-01-28 14:38:56,094 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=33
# *********************
#
# 31 HSI download
# 2022-01-28 14:39:06,163 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=34, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.01038 data
# HK.01038 histocial data download are finished!
# 2022-01-28 14:39:11,468 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=34
# *********************
#
# 32 HSI download
# 2022-01-28 14:39:21,501 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=35, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.01044 data
# HK.01044 histocial data download are finished!
# 2022-01-28 14:39:27,332 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=35
# *********************
#
# 33 HSI download
# 2022-01-28 14:39:37,396 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=36, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.01093 data
# HK.01093 histocial data download are finished!
# 2022-01-28 14:39:42,738 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=36
# *********************
#
# 34 HSI download
# 2022-01-28 14:39:52,786 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=37, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.01109 data
# HK.01109 histocial data download are finished!
# 2022-01-28 14:39:58,135 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=37
# *********************
#
# 35 HSI download
# 2022-01-28 14:40:08,217 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=38, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.01113 data
# HK.01113 histocial data download are finished!
# 2022-01-28 14:40:11,762 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=38
# *********************
#
# 36 HSI download
# 2022-01-28 14:40:21,801 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=39, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.01177 data
# HK.01177 histocial data download are finished!
# 2022-01-28 14:40:27,146 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=39
# *********************
#
# 37 HSI download
# 2022-01-28 14:40:37,302 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=40, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.01211 data
# HK.01211 histocial data download are finished!
# 2022-01-28 14:40:42,818 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=40
# *********************
#
# 38 HSI download
# 2022-01-28 14:40:52,916 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=41, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.01299 data
# HK.01299 histocial data download are finished!
# 2022-01-28 14:40:58,908 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=41
# *********************
#
# 39 HSI download
# 2022-01-28 14:41:08,958 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=42, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.01398 data
# HK.01398 histocial data download are finished!
# 2022-01-28 14:41:14,999 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=42
# *********************
#
# 40 HSI download
# 2022-01-28 14:41:25,041 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=43, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.01810 data
# HK.01810 histocial data download are finished!
# 2022-01-28 14:41:26,739 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=43
# *********************
#
# 41 HSI download
# 2022-01-28 14:41:36,778 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=44, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.01876 data
# HK.01876 histocial data download are finished!
# 2022-01-28 14:41:37,798 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=44
# *********************
#
# 42 HSI download
# 2022-01-28 14:41:47,827 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=45, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.01928 data
# HK.01928 histocial data download are finished!
# 2022-01-28 14:41:53,920 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=45
# *********************
#
# 43 HSI download
# 2022-01-28 14:42:03,955 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=46, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.01997 data
# HK.01997 histocial data download are finished!
# 2022-01-28 14:42:06,111 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=46
# *********************
#
# 44 HSI download
# 2022-01-28 14:42:16,161 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=47, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.02007 data
# HK.02007 histocial data download are finished!
# 2022-01-28 14:42:21,423 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=47
# *********************
#
# 45 HSI download
# 2022-01-28 14:42:31,460 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=48, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.02018 data
# HK.02018 histocial data download are finished!
# 2022-01-28 14:42:37,238 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=48
# *********************
#
# 46 HSI download
# 2022-01-28 14:42:47,289 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=49, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.02020 data
# HK.02020 histocial data download are finished!
# 2022-01-28 14:42:52,330 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=49
# *********************
#
# 47 HSI download
# 2022-01-28 14:43:02,370 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=50, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.02269 data
# HK.02269 histocial data download are finished!
# 2022-01-28 14:43:04,582 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=50
# *********************
#
# 48 HSI download
# 2022-01-28 14:43:14,601 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=51, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.02313 data
# HK.02313 histocial data download are finished!
# 2022-01-28 14:43:19,984 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=51
# *********************
#
# 49 HSI download
# 2022-01-28 14:43:30,030 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=52, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.02318 data
# HK.02318 histocial data download are finished!
# 2022-01-28 14:43:35,625 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=52
# *********************
#
# 50 HSI download
# 2022-01-28 14:43:45,732 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=53, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.02319 data
# HK.02319 histocial data download are finished!
# 2022-01-28 14:43:51,222 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=53
# *********************
#
# 51 HSI download
# 2022-01-28 14:44:01,269 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=54, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.02331 data
# HK.02331 histocial data download are finished!
# 2022-01-28 14:44:06,362 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=54
# *********************
#
# 52 HSI download
# 2022-01-28 14:44:16,490 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=55, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.02382 data
# HK.02382 histocial data download are finished!
# 2022-01-28 14:44:22,729 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=55
# *********************
#
# 53 HSI download
# 2022-01-28 14:44:32,910 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=56, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.02388 data
# HK.02388 histocial data download are finished!
# 2022-01-28 14:44:38,153 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=56
# *********************
#
# 54 HSI download
# 2022-01-28 14:44:48,197 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=57, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.02628 data
# HK.02628 histocial data download are finished!
# 2022-01-28 14:44:53,547 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=57
# *********************
#
# 55 HSI download
# 2022-01-28 14:45:03,587 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=58, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.02688 data
# HK.02688 histocial data download are finished!
# 2022-01-28 14:45:09,609 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=58
# *********************
#
# 56 HSI download
# 2022-01-28 14:45:19,655 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=59, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.03690 data
# HK.03690 histocial data download are finished!
# 2022-01-28 14:45:21,227 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=59
# *********************
#
# 57 HSI download
# 2022-01-28 14:45:31,261 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=60, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.03968 data
# HK.03968 histocial data download are finished!
# 2022-01-28 14:45:37,058 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=60
# *********************
#
# 58 HSI download
# 2022-01-28 14:45:47,109 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=61, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.03988 data
# HK.03988 histocial data download are finished!
# 2022-01-28 14:45:53,026 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=61
# *********************
#
# 59 HSI download
# 2022-01-28 14:46:03,061 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=62, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.06098 data
# HK.06098 histocial data download are finished!
# 2022-01-28 14:46:04,865 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=62
# *********************
#
# 60 HSI download
# 2022-01-28 14:46:14,895 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=63, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.06862 data
# HK.06862 histocial data download are finished!
# 2022-01-28 14:46:16,466 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=63
# *********************
#
# 61 HSI download
# 2022-01-28 14:46:26,496 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=64, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.09618 data
# HK.09618 histocial data download are finished!
# 2022-01-28 14:46:27,140 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=64
# *********************
#
# 62 HSI download
# 2022-01-28 14:46:37,153 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=65, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.09988 data
# HK.09988 histocial data download are finished!
# 2022-01-28 14:46:38,078 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=65
# *********************
#
# 63 HSI download
# 2022-01-28 14:46:48,104 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=66, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.09999 data
# HK.09999 histocial data download are finished!
# 2022-01-28 14:46:48,847 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=66
# *********************

# %% [markdown]
# ## Download HSI Historical Data

# %%
stock_code = 'HK.800000'
futu_get_historical_data(stock_code)
# Out:
# 2022-01-28 15:14:48,394 | 1540 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=69, host=127.0.0.1, port=11111, user_id=18813346
# Start downloading HK.800000 data
# HK.800000 histocial data download are finished!
# 2022-01-28 15:14:54,396 | 1540 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=69

# %% [markdown]
# **The download data is moved to the DataSource folder in the root**
