# %% [markdown]
# # Step2: Data Selection from HK.HSI Constituent (恒指成份股)

# %% [markdown]
# ---
# **What does this notebook do?**
# - Step1 downloads all the 64 HK HSI Constituent data
# - The next step is to select which ones to use for the research.
# - As the project needs stock price data from Jan 1st, 2012 to Jan 1st, 2022 for each one stock, this notebook will select the stocks fulfilling this requirement
# - **Please notice that you can SKIP RUNNING THROUGH this notebook if you are planning to use the stocks data given inside the [DataSource](../DataSource), please go directly to the step3**
#
# **How to choose the stocks?**
# - HANG SENG Bank has published a report on HANG SENG INDEX, the [full report can be found here](https://www.hsi.com.hk/static/uploads/contents/en/dl_centre/factsheets/hsie.pdf)
# - The 50 stock lists are stored in a csv file in [HSI50_Stock_list in the DataSource](../DataSource/HSI50_Stock_list.csv)
# - The report gives the summary of top 50 stocks' information, including industry, share type and weight, etc
# - Combined with the timing requirement, this research will uses the stocks that fulfill the timing requirement within these 50 stocks
#
# **To-Do List**
# 1. Find stocks with listing date before '2012-1-1' from the 64 HSI Constituent data
# 2. Find stocks in the HSI Top 50 stocks before '2012-1-1'
# 3. Make Decisions on which group of data to use
# ---

# %% [markdown]
# # DataSource Overview

# %%
import pandas as pd
HSI_64 = pd.read_csv('../DataSource/full_hsi_stock_list.csv')
HSI_top_50 = pd.read_csv('../DataSource/HSI50_Stock_list.csv')

# %%
HSI_64.head()
# Out:
#        code  lot_size stock_name  stock_owner  stock_child_type stock_type  \
# 0  HK.00001       500         长和          NaN               NaN      STOCK
# 1  HK.00002       500       中电控股          NaN               NaN      STOCK
# 2  HK.00003      1000     香港中华煤气          NaN               NaN      STOCK
# 3  HK.00005       400       汇丰控股          NaN               NaN      STOCK
# 4  HK.00006       500       电能实业          NaN               NaN      STOCK
#
#     list_time       stock_id  main_contract  last_trade_time
# 0  2015-03-18  4440996184065          False              NaN
# 1  1970-01-01              2          False              NaN
# 2  1970-01-01              3          False              NaN
# 3  1970-01-01              5          False              NaN
# 4  1976-08-16              6          False              NaN

# %%
HSI_top_50.head()
# Out:
#    Stock Code     ISIN CODE   Company Name Industry Classification  \
# 0         700  KYG875721634        TENCENT  Information Technology
# 1           5  GB0005405286  HSBC HOLDINGS              Financials
# 2        3690  KYG596691041      MEITUAN-W  Information Technology
# 3        1299  HK0000069689            AIA              Financials
# 4        9988  KYG017191142        BABA-SW  Information Technology
#
#                      Share Type  Weighting (%)
# 0  Other HK-listed Mainland Co.           8.00
# 1                   HK Ordinary           7.71
# 2  Other HK-listed Mainland Co.           7.62
# 3                   HK Ordinary           7.53
# 4  Other HK-listed Mainland Co.           7.13

# %% [markdown]
# # Select the Top 50 HSI Constituent Data with list time before 2012-1-1

# %%
def formatting_HSI_top_50_stock_code():
    """
    This function transfers the 50 stock codes from HANG SENG BANK report
    to the same stock code format in the historical data downloaded via 
    FUTU Open API
    """
    HSI50_list = HSI_top_50['Stock Code'].tolist()
    update_HSI50_list = []
    for i in HSI50_list:
        add_zero_num = 5 - len(str(i))
        name = 'HK.' + '0'*add_zero_num + str(i)
        update_HSI50_list.append(name)
    HSI_top_50['Stock Code'] = update_HSI50_list
    return HSI_top_50

# %%
HSI_top_50 = formatting_HSI_top_50_stock_code()
HSI_top_50.head()
# Out:
#   Stock Code     ISIN CODE   Company Name Industry Classification  \
# 0   HK.00700  KYG875721634        TENCENT  Information Technology
# 1   HK.00005  GB0005405286  HSBC HOLDINGS              Financials
# 2   HK.03690  KYG596691041      MEITUAN-W  Information Technology
# 3   HK.01299  HK0000069689            AIA              Financials
# 4   HK.09988  KYG017191142        BABA-SW  Information Technology
#
#                      Share Type  Weighting (%)
# 0  Other HK-listed Mainland Co.           8.00
# 1                   HK Ordinary           7.71
# 2  Other HK-listed Mainland Co.           7.62
# 3                   HK Ordinary           7.53
# 4  Other HK-listed Mainland Co.           7.13

# %%
df = HSI_top_50.merge(HSI_64, how='left', left_on='Stock Code', right_on='code')
print(f"There are {len(df[df['list_time']>'2012-1-1'])} stocks listed after 2012-1-1, out of top 50 HSI Constituent Stock\nListed here below")
df[df['list_time']>'2012-1-1']
# Out:
# There are 11 stocks listed after 2012-1-1, out of top 50 HSI Constituent Stock
# Listed here below
#    Stock Code     ISIN CODE  Company Name    Industry Classification  \
# 2    HK.03690  KYG596691041     MEITUAN-W     Information Technology
# 4    HK.09988  KYG017191142       BABA-SW     Information Technology
# 8    HK.02269  KYG970081173      WUXI BIO                 Healthcare
# 9    HK.01810  KYG9830T1067      XIAOMI-W     Information Technology
# 18   HK.09618  KYG8208B1014         JD-SW     Information Technology
# 23   HK.00001  KYG217651051  CKH HOLDINGS              Conglomerates
# 33   HK.01113  KYG2177B1014      CK ASSET  Properties & Construction
# 38   HK.06098  KYG2453A1085   CG SERVICES  Properties & Construction
# 39   HK.09999  KYG6427A1022        NTES-S     Information Technology
# 43   HK.01997  KYG9593A1040    WHARF REIC  Properties & Construction
# 47   HK.00968  KYG9829N1025   XINYI SOLAR                Industrials
#
#                       Share Type  Weighting (%)      code  lot_size  \
# 2   Other HK-listed Mainland Co.           7.62  HK.03690       100
# 4   Other HK-listed Mainland Co.           7.13  HK.09988       100
# 8                    HK Ordinary           2.64  HK.02269       500
# 9   Other HK-listed Mainland Co.           2.63  HK.01810       200
# 18  Other HK-listed Mainland Co.           1.34  HK.09618        50
# 23                   HK Ordinary           1.07  HK.00001       500
# 33                   HK Ordinary           0.78  HK.01113       500
# 38   Other HK-listed Mainland Co           0.65  HK.06098      1000
# 39  Other HK-listed Mainland Co.           0.64  HK.09999       100
# 43                   HK Ordinary           0.57  HK.01997      1000
# 47   Other HK-listed Mainland Co           0.51  HK.00968      2000
#
#    stock_name  stock_owner  stock_child_type stock_type   list_time  \
# 2        美团-W          NaN               NaN      STOCK  2018-09-20
# 4     阿里巴巴-SW          NaN               NaN      STOCK  2019-11-26
# 8        药明生物          NaN               NaN      STOCK  2017-06-13
# 9      小米集团-W          NaN               NaN      STOCK  2018-07-09
# 18    京东集团-SW          NaN               NaN      STOCK  2020-06-18
# 23         长和          NaN               NaN      STOCK  2015-03-18
# 33       长实集团          NaN               NaN      STOCK  2015-06-03
# 38      碧桂园服务          NaN               NaN      STOCK  2018-06-19
# 39       网易-S          NaN               NaN      STOCK  2020-06-11
# 43      九龙仓置业          NaN               NaN      STOCK  2017-11-23
# 47       信义光能          NaN               NaN      STOCK  2013-12-12
#
#           stock_id  main_contract  last_trade_time
# 2   76364518526570          False              NaN
# 4   78224239372036          False              NaN
# 8   74371653699805          False              NaN
# 9   76033806042898          False              NaN
# 18  79100412700050          False              NaN
# 23   4440996184065          False              NaN
# 33  71244917507161          False              NaN
# 38  75965086570450          False              NaN
# 39  79083232831247          False              NaN
# 43  75067438401485          False              NaN
# 47  68934225101768          False              NaN

# %%
df = df[df['list_time']<='2012-1-1'].reset_index(drop=True)
df = df.drop(columns=['code', 'stock_owner', 'stock_child_type', 'stock_type', 'stock_id', 'main_contract', 'last_trade_time'])
df.to_csv('../DataSource/research_use_39_stocks.csv', index=False)
df
# Out:
#    Stock Code     ISIN CODE     Company Name    Industry Classification  \
# 0    HK.00700  KYG875721634          TENCENT     Information Technology
# 1    HK.00005  GB0005405286    HSBC HOLDINGS                 Financials
# 2    HK.01299  HK0000069689              AIA                 Financials
# 3    HK.00939  CNE1000002H1              CCB                 Financials
# 4    HK.00388  HK0388045442             HKEX                 Financials
# 5    HK.02318  CNE1000003X6          PING AN                 Financials
# 6    HK.01398  CNE1000003G1             ICBC                 Financials
# 7    HK.00941  HK0941009539     CHINA MOBILE         Telecommunications
# 8    HK.03968  CNE1000002M1          CM BANK                 Financials
# 9    HK.00669  HK0669013440   TECHTRONIC IND     Consumer Discretionary
# 10   HK.01211  CNE100000296      BYD COMPANY     Consumer Discretionary
# 11   HK.03988  CNE1000001Z5    BANK OF CHINA                 Financials
# 12   HK.02331  KYG5496K1242          LI NING     Consumer Discretionary
# 13   HK.02382  KYG8586D1097    SUNNY OPTICAL                Industrials
# 14   HK.00002  HK0002007356     CLP HOLDINGS                  Utilities
# 15   HK.00823  HK0823032773        LINK REIT  Properties & Construction
# 16   HK.00883  HK0883013259            CNOOC                     Energy
# 17   HK.00003  HK0003000038   HK & CHINA GAS                  Utilities
# 18   HK.02313  KYG8087W1015    SHENZHOU INTL     Consumer Discretionary
# 19   HK.02020  KYG040111059      ANTA SPORTS     Consumer Discretionary
# 20   HK.00175  KYG3777B1032       GEELY AUTO     Consumer Discretionary
# 21   HK.00016  HK0016000132          SHK PPT  Properties & Construction
# 22   HK.02319  KYG210961051    MENGNIU DAIRY           Consumer Staples
# 23   HK.02688  KYG3066L1014       ENN ENERGY                  Utilities
# 24   HK.00011  HK0011000095   HANG SENG BANK                 Financials
# 25   HK.01109  KYG2108Y1052   CHINA RES LAND  Properties & Construction
# 26   HK.00291  HK0291001490   CHINA RES BEER           Consumer Staples
# 27   HK.02628  CNE1000002L3       CHINA LIFE                 Financials
# 28   HK.02388  HK2388011192    BOC HONG KONG                 Financials
# 29   HK.00027  HK0027032686       GALAXY ENT     Consumer Discretionary
# 30   HK.00386  CNE1000002Q2     SINOPEC CORP                     Energy
# 31   HK.00066  HK0066009694  MTR CORPORATION     Consumer Discretionary
# 32   HK.01093  HK1093012172      CSPC PHARMA                 Healthcare
# 33   HK.00857  CNE1000003W8       PETROCHINA                     Energy
# 34   HK.00688  HK0688002218   CHINA OVERSEAS  Properties & Construction
# 35   HK.00006  HK0006000050     POWER ASSETS                  Utilities
# 36   HK.00960  KYG5635P1090    LONGFOR GROUP  Properties & Construction
# 37   HK.01177  KYG8167W1380    SINO BIOPHARM                 Healthcare
# 38   HK.00267  HK0267001375            CITIC              Conglomerates
#
#                       Share Type  Weighting (%)  lot_size stock_name  \
# 0   Other HK-listed Mainland Co.           8.00       100       腾讯控股
# 1                    HK Ordinary           7.71       400       汇丰控股
# 2                    HK Ordinary           7.53       200       友邦保险
# 3                        H Share           4.63      1000       建设银行
# 4                    HK Ordinary           4.35       100      香港交易所
# 5                        H Share           2.82       500       中国平安
# 6                        H Share           2.57      1000       工商银行
# 7                       Red Chip           2.28       500       中国移动
# 8                        H Share           1.87       500       招商银行
# 9                    HK Ordinary           1.80       500       创科实业
# 10                       H Share           1.77       500      比亚迪股份
# 11                       H Share           1.77      1000       中国银行
# 12  Other HK-listed Mainland Co.           1.52       500         李宁
# 13  Other HK-listed Mainland Co.           1.39       100     舜宇光学科技
# 14                   HK Ordinary           1.26       500       中电控股
# 15                   HK Ordinary           1.14       100     领展房产基金
# 16                      Red Chip           1.14      1000     中国海洋石油
# 17                   HK Ordinary           1.08      1000     香港中华煤气
# 18  Other HK-listed Mainland Co.           1.07       100       申洲国际
# 19  Other HK-listed Mainland Co.           1.00       200       安踏体育
# 20  Other HK-listed Mainland Co.           0.99      1000       吉利汽车
# 21                   HK Ordinary           0.98       500      新鸿基地产
# 22                      Red Chip           0.97      1000       蒙牛乳业
# 23  Other HK-listed Mainland Co.           0.92       100       新奥能源
# 24                   HK Ordinary           0.86       100       恒生银行
# 25                      Red Chip           0.83      2000       华润置地
# 26                      Red Chip           0.82      2000       华润啤酒
# 27                       H Share           0.76      1000       中国人寿
# 28                   HK Ordinary           0.75       500       中银香港
# 29                   HK Ordinary           0.70      1000       银河娱乐
# 30                       H Share           0.70      2000   中国石油化工股份
# 31                   HK Ordinary           0.62       500       港铁公司
# 32  Other HK-listed Mainland Co.           0.60      2000       石药集团
# 33                       H Share           0.58      2000     中国石油股份
# 34                      Red Chip           0.56       500     中国海外发展
# 35                   HK Ordinary           0.53       500       电能实业
# 36   Other HK-listed Mainland Co           0.53       500       龙湖集团
# 37   Other HK-listed Mainland Co           0.49      1000     中国生物制药
# 38                      Red Chip           0.44      1000       中信股份
#
#      list_time
# 0   2004-06-16
# 1   1970-01-01
# 2   2010-10-29
# 3   2005-10-27
# 4   2000-06-27
# 5   2004-06-24
# 6   2006-10-27
# 7   1997-10-23
# 8   2006-09-22
# 9   1990-12-17
# 10  2002-07-31
# 11  2006-06-01
# 12  2004-06-28
# 13  2007-06-15
# 14  1970-01-01
# 15  2005-11-25
# 16  2001-02-28
# 17  1970-01-01
# 18  2005-11-24
# 19  2007-07-10
# 20  1973-02-23
# 21  1972-09-08
# 22  2004-06-10
# 23  2002-06-03
# 24  1972-06-20
# 25  1996-11-08
# 26  1970-01-01
# 27  2003-12-18
# 28  2002-07-25
# 29  1991-10-07
# 30  2000-10-19
# 31  2000-10-05
# 32  1994-06-21
# 33  2000-04-07
# 34  1992-08-20
# 35  1976-08-16
# 36  2009-11-19
# 37  2003-12-08
# 38  1986-02-26

# %% [markdown]
# # Data Formatting Before Prediction & Optimization

# %%
def format_date():
    """
    This function formats the dataset into a better format
    before using them for prediction and optimization
    """
    import pandas as pd
    import datetime as dt
    stock_list = pd.read_csv('../DataSource/research_use_39_stocks.csv')['Stock Code'].tolist()
    # Add the Hang Seng Index stock prices to the stock_list
    stock_list.append('HK.800000')
    data_file_location_list = [str('../DataSource/StockData/' + i + '.csv') for i in stock_list]

    for data_file in data_file_location_list:
        df = pd.read_csv(data_file)
        df.rename(columns = {'time_key':'date'}, inplace = True)
        df['date'] = pd.to_datetime(df['date']).dt.date
        df = df.drop([col for col in df.columns if 'Unnamed: 0' in col],axis=1)
        df.to_csv(data_file, index=False)

# %%
format_date()
